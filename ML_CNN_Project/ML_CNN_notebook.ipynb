# %% [markdown]
# Primero primerísimo esta creo que es una buena estrcutura para la exposición:
#
# Sección	Tiempo
# Motivación	5 min
# Redes neuronales tradicionales	6 min
# Convolución y filtros	8 min
# Componentes de una CNN	10 min
# Implementación de una CNN	8 min
# Comparación CNN vs MLP	6 min
# Arquitecturas modernas	6 min
# Aplicaciones en astronomía y conclusiones 5min
#
# Debería dividir esto entre Felipe y yo y cada uno simplemente descarga el notebook del otro y hacemos un notebook en conjunto oooooooo podemos trabajar en un google colab xd
#
# Notebook 1. "Las imágenes son matrices"
#
# Cargar MNIST o CIFAR-10.
# Visualizar imágenes.
# Mostrar su representación matricial.
#
# Notebook 2. "Convoluciones manuales"
#
# Aplicar kernels clásicos (bordes, desenfoque, nitidez) con scipy.signal.convolve2d.
# Experimentar con distintos tamaños de kernel y observar el efecto.
#
# Notebook 3. "Construcción de una CNN"
#
# Implementar una CNN sencilla con TensorFlow/Keras.
# Entrenar sobre MNIST.
# Graficar curvas de pérdida y precisión.
#
# Notebook 4. "MLP vs CNN"
#
# Entrenar una red densa y una CNN bajo condiciones similares.
# Comparar número de parámetros, tiempo de entrenamiento, precisión y matriz de confusión.
#
# Notebook 5. "¿Qué está viendo la CNN?"
#
# Visualizar los mapas de activación de las primeras capas.
# Mostrar cómo los primeros filtros detectan bordes y cómo las capas profundas responden a patrones más complejos.
#
# Pensaría en algo así para dividir las secciones grandes y que cada una de esta contenga ejemplos de código de lo que estamos hablando xd
